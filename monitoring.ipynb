# %% [markdown]
# # challenge notebook
#
# PulseNet has contacted us regarding the performance monitoring of the fine-tuned model we created for them. They want to see how the `training_loss` and `train_mean_token_accuracy` change in each `step` of the model training process.
#
# Your task is to first extract the needed information from the trained model and use line charts to visualize `train_mean_token_accuracy` vs `step` and one line chart for `training_loss` vs `step`.
#
# Follow the instructions in the notebook to complete the challenge task.

# %% [markdown]
# Installing the needed Modules

# %%
# !pip install openai==1.7.2 python-dotenv
# !pip install httpx==0.27.2
# Out:
# Requirement already satisfied: openai==1.7.2 in /usr/local/lib/python3.12/dist-packages (1.7.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.7.2) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.7.2) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.7.2) (0.27.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.7.2) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai==1.7.2) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai==1.7.2) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.12/dist-packages (from openai==1.7.2) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai==1.7.2) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai==1.7.2) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai==1.7.2) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.7.2) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.7.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.7.2) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.7.2) (0.4.2)
# Requirement already satisfied: httpx==0.27.2 in /usr/local/lib/python3.12/dist-packages (0.27.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.2) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.2) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.2) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.2) (3.11)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.2) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx==0.27.2) (0.16.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx==0.27.2) (4.15.0)

# %% [markdown]
# Run the code block below to import the necessary modules and set up the OpenAI API. <br>
# `Hint:` Do not forget to upload the `.env` file

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
import matplotlib.pyplot as plt

load_dotenv(dotenv_path='apikey.env.txt')

APIKEY = os.getenv("APIKEY")
ORGID = os.getenv("ORGID")

client = OpenAI(
  organization= ORGID,
  api_key=APIKEY
)

# %% [markdown]
# Run the code block below to retrieve all the fine-tuned models that you have trained on the OpenAI servers. And select the latest fine-tuning job from the list.

# %%
# Retrieving the list of fine-tuning jobs from the OpenAI client
fine_tuning_jobs = list(client.fine_tuning.jobs.list())

# Selecting the latest fine-tuning job from the list
latest_job = fine_tuning_jobs[-1]
latest_job
# Out:
# FineTuningJob(id='ftjob-NJXuJ7CPTupTQY5d764BGh1U', created_at=1772666909, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-3.5-turbo-0125:personal::DFq68PGY', finished_at=1772667556, hyperparameters=Hyperparameters(n_epochs=1, batch_size=1, learning_rate_multiplier=2), model='gpt-3.5-turbo-0125', object='fine_tuning.job', organization_id='org-6rfT6ij44SUkzW2GbwgKQj8h', result_files=['file-5qYFnq5We3fynZ58Y29d6C'], status='succeeded', trained_tokens=36208, training_file='file-Wpe6N9AWhit6PbT7gjme7M', validation_file=None, user_provided_suffix=None, seed=1890698314, estimated_finish=None, integrations=[], metadata=None, usage_metrics=None, shared_with_openai=False, eval_id=None, internal_worker_backend=None, internal_peashooter_execution=None, train_experiment_id=None, eval_experiment_id=None, method={'type': 'supervised', 'supervised': {'hyperparameters': {'n_epochs': 1, 'batch_size': 1, 'learning_rate_multiplier': 2.0}}})

# %% [markdown]
# Now retrieve all the event messages from the retrieved job and put it inside a variable called `events`

# %%
# write my code here
events = client.fine_tuning.jobs.list_events(fine_tuning_job_id=latest_job.id, limit=10)
print(list(events))
# Out:
# [FineTuningJobEvent(id='ftevent-Or9IjEF1Gl4Kz30TAnfmfoyW', created_at=1772668284, level='info', message='The job has successfully completed', object='fine_tuning.job.event', data={}, type='message'), FineTuningJobEvent(id='ftevent-8OrNYjl0PVs4Pgum8qS4Seig', created_at=1772668282, level='info', message='Usage policy evaluations completed, model is now enabled for sampling', object='fine_tuning.job.event', data={}, type='message'), FineTuningJobEvent(id='ftevent-CGZsBjyz8mmYYUp3m8Ar8RyI', created_at=1772668282, level='info', message='Moderation checks for snapshot ft:gpt-3.5-turbo-0125:personal::DFq68PGY passed.', object='fine_tuning.job.event', data={'blocked': False, 'results': [{'flagged': False, 'category': 'harassment/threatening', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'sexual', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'sexual/minors', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'propaganda', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'hate', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'hate/threatening', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'illicit', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'violence', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'advice', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'self-harm/intent', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'self-harm/instructions', 'enforcement': 'non_blocking'}, {'flagged': False, 'category': 'sensitive', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'highly-sensitive', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'biological threats', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'cyber security threats', 'enforcement': 'blocking'}], 'finetuned_model_checkpoint_id': 'ft:gpt-3.5-turbo-0125:personal::DFq68PGY'}, type='moderation_checks'), FineTuningJobEvent(id='ftevent-I9YhFpEqbJhEpZJkDshgMlrA', created_at=1772667557, level='info', message='Evaluating model against our usage policies', object='fine_tuning.job.event', data={}, type='message'), FineTuningJobEvent(id='ftevent-Xz27Vp5omqbXS2MNSCL2dhWV', created_at=1772667557, level='info', message='New fine-tuned model created', object='fine_tuning.job.event', data={}, type='message'), FineTuningJobEvent(id='ftevent-LJEQZ3pxuwg1Ts66QE2hRSbc', created_at=1772667549, level='info', message='Step 268/268: training loss=0.49', object='fine_tuning.job.event', data={'step': 268, 'train_loss': 0.48527655005455017, 'total_steps': 268, 'train_mean_token_accuracy': 0.9629629629629629}, type='metrics'), FineTuningJobEvent(id='ftevent-Yhl4mvPa5euYuEsDcBiMU1OZ', created_at=1772667546, level='info', message='Step 267/268: training loss=0.05', object='fine_tuning.job.event', data={'step': 267, 'train_loss': 0.05116927996277809, 'total_steps': 268, 'train_mean_token_accuracy': 0.96}, type='metrics'), FineTuningJobEvent(id='ftevent-rujq2z8JGM4WFhD4UJH1ABIq', created_at=1772667546, level='info', message='Step 266/268: training loss=0.49', object='fine_tuning.job.event', data={'step': 266, 'train_loss': 0.4879915416240692, 'total_steps': 268, 'train_mean_token_accuracy': 0.9629629629629629}, type='metrics'), FineTuningJobEvent(id='ftevent-rXDswqZr93aH96eCWA3X6Dit', created_at=1772667543, level='info', message='Step 265/268: training loss=0.03', object='fine_tuning.job.event', data={'step': 265, 'train_loss': 0.0318104550242424, 'total_steps': 268, 'train_mean_token_accuracy': 1.0}, type='metrics'), FineTuningJobEvent(id='ftevent-bj84lkUQTfv0ESkn5HdpUqsL', created_at=1772667543, level='info', message='Step 264/268: training loss=0.05', object='fine_tuning.job.event', data={'step': 264, 'train_loss': 0.047913819551467896, 'total_steps': 268, 'train_mean_token_accuracy': 0.96}, type='metrics'), FineTuningJobEvent(id='ftevent-1cOzLvGSHMnSvBBWX8DofrLK', created_at=1772667540, level='info', message='Step 263/268: training loss=0.04', object ...

# %% [markdown]
# Loop through the `events` and extract the following information from each event object and store them in different lists:
# - steps
# - training_loss
# - train_mean_token_accuracy
#
# `Hint:` Each event object inside the `events` list has a property called data. You can find what you need there!

# %%
# Initialize empty lists to store the extracted information
steps, training_loss, train_mean_token_accuracy = [], [], []

# Loop through each event object in the events list
# Extract and append the step, training loss, and train_mean_token_accuracy from the event object
for e in events:
  # Only process events of type 'metrics' which contain the desired data
  if e.type == 'metrics' and e.data:
    steps.append(e.data['step'])
    training_loss.append(e.data['train_loss'])
    train_mean_token_accuracy.append(e.data['train_mean_token_accuracy'])

# %% [markdown]
# Create a line chart using Matplotlib to visualize how training loss changes over learning steps.

# %%
# write my code here
plt.plot(steps, training_loss)
plt.xlabel('steps')
plt.ylabel('training_loss')
# Out:
# Text(0, 0.5, 'training_loss')

# %% [markdown]
# Now create a line chart using Matplotlib to visualize how train_mean_token_accuracy changes over learning steps.

# %%
# write your code here
plt.plot(steps, train_mean_token_accuracy)
plt.xlabel('steps')
plt.ylabel('train_mean_token_accuracy')
# Out:
# Text(0, 0.5, 'train_mean_token_accuracy')

# %% [markdown]
# 💡 A good model fine-tuning is indicated by a decrease in training loss over the learning steps and an increase in training mean token accuracy over the steps.
#
# Look at the charts you created to assess if your training procedure was effective.
